# %% [markdown]
# <a href="https://colab.research.google.com/github/jvallalta/ia3/blob/main/4_MLPvsRNN_Ejercicio_TF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![IDAL](https://i.imgur.com/tIKXIG1.jpg)
#
# #**Máster en Inteligencia Artificial Avanzada y Aplicada:  IA^3**
# ---

# %% [markdown]
# #<strong><center>Series temporales con RNNs y MLP en KERAS: Ejercicio</center></strong>

# %% [markdown]
# En este ejercicio se propone realizar un estudio similar al del anterior notebook. En este caso se va a emplear un dataset de datos reales

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %% [markdown]
# Importamos el fichero de repositorio

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/Sunspots.csv \
    -O /tmp/sunspots.csv
# Out:
# --2021-02-05 19:34:07--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/Sunspots.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.142.128, 74.125.195.128, 142.250.107.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.142.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70827 (69K) [application/octet-stream]
# Saving to: ‘/tmp/sunspots.csv’
#
# /tmp/sunspots.csv   100%[===================>]  69.17K  --.-KB/s    in 0.001s
#
# 2021-02-05 19:34:07 (114 MB/s) - ‘/tmp/sunspots.csv’ saved [70827/70827]

# %% [markdown]
# Lo cargamos y ploteamos para ver su aspecto y comprobar que todo ha ido bien:

# %%
import csv
time_step = []
sunspots = []

with open('/tmp/sunspots.csv') as csvfile:
  reader = csv.reader(csvfile, delimiter=',')
  next(reader)
  for row in reader:
    sunspots.append(float(row[2]))
    time_step.append(int(row[0]))

series = np.array(sunspots)
time = np.array(time_step)
plt.figure(figsize=(10, 6))
plot_series(time, series)

# %% [markdown]
# ##Inicio del ejercicio

# %% [markdown]
# Preparación de parámetros
# Configura los parámetros segun estas directrices iniciales:
# * conjunto de entrenamiento sea de 3000 muestras y el resto de validación
# * Enventanado de 60 muestras
# * Tamaño de lote de 128
# * Tamaño de mezcla de buffer de 1000

# %%
# Tu código aquí: 
split_time = 3000
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]


window_size = 60
batch_size = 128
shuffle_buffer_size = 1000

# %% [markdown]
# La función que prepara el dataset a partir del enventanado y parámetros especificados se mantiene igual

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
  dataset = tf.data.Dataset.from_tensor_slices(series)
  dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
  dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
  dataset = dataset.shuffle(shuffle_buffer).map(lambda window: (window[:-1], window[-1]))
  dataset = dataset.batch(batch_size).prefetch(1)
  return dataset

# %% [markdown]
# ## Modelo con RNN

# %% [markdown]
# Crea el dataset empleando la función anterior `windowed_dataset`:

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(51)
np.random.seed(51)

# Tu código aquí: 
dataset = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# %% [markdown]
# Define el modelo de RNN simple con 2 capas de 40 y 40 neuronas respectivamente y la misma arquitectura del ejercicio anterior

# %%
# Tu código aquí: 
model = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                      input_shape=[None]),
  tf.keras.layers.SimpleRNN(40, return_sequences=True),
  tf.keras.layers.SimpleRNN(40),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 100.0)
])

# %% [markdown]
# Comprueba su arquitectura y cantidad de parámetros

# %%
# Tu código aquí: 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda (Lambda)              (None, None, 1)           0
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, None, 40)          1680
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 40)                3240
# _________________________________________________________________
# dense (Dense)                (None, 1)                 41
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 1)                 0
# =================================================================
# Total params: 4,961
# Trainable params: 4,961
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Antes de su entrenamiento definitivo, realiza una exploración sobre el conjunto de entrenamiento para determinar un learning rate óptimo

# %%
# Tu código aquí: 

train_set = dataset 

lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-8 * 10**(epoch / 20))

optimizer = tf.keras.optimizers.SGD(lr=1e-8, momentum=0.9)

model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

history = model.fit(train_set, epochs=100, callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 23/23 [==============================] - 5s 91ms/step - loss: 142.6576 - mae: 143.1573
# Epoch 2/100
# 23/23 [==============================] - 2s 89ms/step - loss: 137.7770 - mae: 138.2761
# Epoch 3/100
# 23/23 [==============================] - 2s 86ms/step - loss: 129.5360 - mae: 130.0350
# Epoch 4/100
# 23/23 [==============================] - 2s 88ms/step - loss: 121.5594 - mae: 122.0587
# Epoch 5/100
# 23/23 [==============================] - 2s 91ms/step - loss: 116.4168 - mae: 116.9163
# Epoch 6/100
# 23/23 [==============================] - 2s 92ms/step - loss: 108.1795 - mae: 108.6793
# Epoch 7/100
# 23/23 [==============================] - 2s 89ms/step - loss: 101.2684 - mae: 101.7679
# Epoch 8/100
# 23/23 [==============================] - 2s 90ms/step - loss: 94.2924 - mae: 94.7913
# %%
plt.semilogx(history.history["lr"], history.history["loss"])
plt.axis([1e-8, 1e-4, 0, 30])
# Out:
# (1e-08, 0.0001, 0.0, 30.0)

# %% [markdown]
# Configura ahora y reentrena con la tasa de lr elegida, tal como hemos hecho en el ejercicio anterior y 200 epochs

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(51)
np.random.seed(51)

# Tu código aquí: 
dataset = windowed_dataset(x_train, window_size, batch_size=batch_size, shuffle_buffer=shuffle_buffer_size)

model = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                      input_shape=[None]),
  tf.keras.layers.SimpleRNN(40, return_sequences=True),
  tf.keras.layers.SimpleRNN(40),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 100.0)])
optimizer = tf.keras.optimizers.SGD(lr=20e-5, momentum=0.9)

model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

history = model.fit(dataset,epochs=100)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 3s 91ms/step - loss: 69.1587 - mae: 69.6568
# Epoch 2/100
# 23/23 [==============================] - 2s 93ms/step - loss: 64.4208 - mae: 64.9190
# Epoch 3/100
# 23/23 [==============================] - 2s 96ms/step - loss: 48.3631 - mae: 48.8607
# Epoch 4/100
# 23/23 [==============================] - 2s 95ms/step - loss: 50.7947 - mae: 51.2918
# Epoch 5/100
# 23/23 [==============================] - 2s 94ms/step - loss: 50.7351 - mae: 51.2315
# Epoch 6/100
# 23/23 [==============================] - 2s 95ms/step - loss: 43.8066 - mae: 44.3037
# Epoch 7/100
# 23/23 [==============================] - 2s 92ms/step - loss: 43.2808 - mae: 43.7778
# Epoch 8/100
# 23/23 [==============================] - 2s 93ms/step - loss: 58.8030 - mae: 59.3020
# Epoch 9/100
# 23/23 [==============================] - 2s 95ms/step - loss: 46.8796 - mae: 47.3770
# Epoch 10/100
# 23/23 [==============================] - 2s 97ms/step - loss: 44.4854 - mae: 44.9828
# Epoch 11/100
# 23/23 [==============================] - 2s 98ms/step - loss: 50.6500 - mae: 51.1471
# Epoch 12/100
# 23/23 [==============================] - 2s 95ms/step - loss: 46.0008 - mae: 46.4982
# Epoch 13/100
# 23/23 [==============================] - 2s 98ms/step - loss: 48.4734 - mae: 48.9712
# Epoch 14/100
# 23/23 [==============================] - 2s 97ms/step - loss: 56.9448 - mae: 57.4426
# Epoch 15/100
# 23/23 [==============================] - 2s 94ms/step - loss: 47.3939 - mae: 47.8914
# Epoch 16/100
# 23/23 [==============================] - 2s 92ms/step - loss: 48.7741 - mae: 49.2716
# Epoch 17/100
# 23/23 [==============================] - 2s 93ms/step - loss: 49.6394 - mae: 50.1366
# Epoch 18/100
# 23/23 [==============================] - 2s 96ms/step - loss: 49.1024 - mae: 49.6001
# Epoch 19/100
# 23/23 [==============================] - 2s 94ms/step - loss: 52.8763 - mae: 53.3731
# Epoch 20/100
# 23/23 [==============================] - 2s 94ms/step - loss: 49.0577 - mae: 49.5557
# Epoch 21/100
# 23/23 [==============================] - 2s 89ms/step - loss: 45.2029 - mae: 45.7002
# Epoch 22/100
# 23/23 [==============================] - 2s 92ms/step - loss: 41.0188 - mae: 41.5138
# Epoch 23/100
# 23/23 [==============================] - 2s 95ms/step - loss: 51.1119 - mae: 51.6087
# Epoch 24/100
# 23/23 [==============================] - 2s 95ms/step - loss: 47.1768 - mae: 47.6747
# Epoch 25/100
# 23/23 [==============================] - 2s 97ms/step - loss: 49.7693 - mae: 50.2659
# Epoch 26/100
# 23/23 [==============================] - 2s 95ms/step - loss: 49.8570 - mae: 50.3552
# Epoch 27/100
# 23/23 [==============================] - 2s 94ms/step - loss: 52.2799 - mae: 52.7764
# Epoch 89/100
# 23/23 [==============================] - 2s 100ms/step - loss: 48.8228 - mae: 49.3205
# Epoch 90/100
# 23/23 [==============================] - 2s 103ms/step - loss: 44.3294 - mae: 44.8251
# Epoch 91/100
# 23/23 [==============================] - 2s 98ms/step - loss: 45.5427 - mae: 46.0416
# Epoch 92/100
# 23/23 [==============================] - 2s 100ms/step - loss: 47.6806 - mae: 48.1776
# Epoch 93/100
# 23/23 [==============================] - 2s 103ms/step - loss: 55.6710 - mae: 56.1693
# Epoch 94/100
# 23/23 [==============================] - 2s 102ms/step - loss: 47.0684 - mae: 47.5641
# Epoch 95/100
# 23/23 [==============================] - 2s 99ms/step - loss: 41.9829 - mae: 42.4794
# Epoch 96/100
# 23/23 [==============================] - 2s 102ms/step - loss: 38.4423 - mae: 38.9386
# Epoch 97/100
# 23/23 [==============================] - 2s 99ms/step - loss: 35.1119 - mae: 35.6076
# Epoch 98/100
# 23/23 [==============================] - 3s 104ms/step - loss: 32.6051 - mae: 33.1004
# Epoch 99/100
# 23/23 [==============================] - 2s 99ms/step - loss: 30.8244 - mae: 31.3197
# Epoch 100/100
# 23/23 [==============================] - 2s 103ms/step - loss: 32.7243 - mae: 33.2200

# %% [markdown]
# Realizamos predicciones y visualizamos resultados igual que en ejemplo anterior

# %%
forecast=[]

# Tu código aquí: 

for time in range(len(series) - window_size):
  forecast.append(model.predict(series[time:time + window_size][np.newaxis]))

forecast = forecast[split_time-window_size:]
results = np.array(forecast)[:, 0, 0]


plt.figure(figsize=(10, 6))

plot_series(time_valid, x_valid)
plot_series(time_valid, results)

# %% [markdown]
# Obtenemos una métrica de error numérica para poder realizar comparaciones:

# %%
# Tu código aquí: 
tf.keras.metrics.mean_absolute_error(x_valid, results).numpy()
# Out:
# 25.298536

# %% [markdown]
# Visualiza el error y la métrica de salida MAE para ver su relación. Los valores los tenemos en la lista history[ ]

# %% [markdown]
# ## Modelo con MLP (*MultiLayer Perceptron*)

# %% [markdown]
# Vamos ahora a plantear un modelo equivalente con la red neuronal multicapa.
#
# Implementa el mismo numero de capas (2) y neuronas por (20 y 10) capa con función de activación "relu"

# %%
# Tu código aquí: 
model2 =

# %% [markdown]
# Comprueba arquitectura y parámetros

# %%
# Tu código aquí:

# %% [markdown]
# Mismos parámetros de compilacion, pérdida y optimizador

# %%
model2.compile(loss="mse", optimizer=tf.keras.optimizers.SGD(lr=1e-6, momentum=0.9))

# %% [markdown]
# Entrena durante el mismo número de epochs (200)

# %%
# Tu código aquí:

# %% [markdown]
# Prediccion y visualización de resultados

# %%
forecast = []

# Tu código aquí:

# %% [markdown]
# Métrica de resultados

# %%
# Tu código aquí:

# %% [markdown]
# Enhorabuena, has llegado al final del ejercicio!

# %% [markdown]
# Ahora reflexiona sobre los resultados obtenidos:
# * ¿Cual ha funcionado mejor?
# * ¿Porqué crees que es?
#
# Repite el entrenamiento variando diferentes parámetros y observa como influyen en los resultados y los tiempos:
# * tamaño del lote
# * arquitectura de la red - nº de neuronas
# * tasa de aprendizaje
# * nº de epochs
# * enventanado

# %% [markdown]
# ##Referencias

# %% [markdown]
# *   Documento inspirado en los ejemplos del repositorio de LaurenceMorone y en su curso de Deep Learning con TensorFlow: https://github.com/lmoroney?tab=repositories
# * Doc oficial Pytorch https://pytorch.org/docs/stable/generated/torch.nn.RNN.html
# * https://pytorch.org/tutorials/intermediate/char_rnn_classification_tutorial.html

# %% [markdown]
# ##Fin del cuaderno
